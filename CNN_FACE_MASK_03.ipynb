# %% [markdown]
# ## Bibliotecas

# %%
import torch
import os
import random
import numpy                as np
import pandas               as pd
import torch.nn.functional  as F
import matplotlib.pyplot    as plt
import seaborn              as sns
import plotly.graph_objects as go
import plotly.express       as px

import tensorflow as tf
from torch.utils.data import Dataset
from torchvision.datasets import ImageFolder
from torchvision.transforms import transforms
from torch.utils.data import DataLoader, random_split
from torchvision import transforms

from PIL                         import Image
from torch                       import nn, optim
from torch.nn.modules            import padding
from torch.nn.modules.activation import ReLU

from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader

from torchvision                 import datasets
from plotly.subplots             import make_subplots
from google.colab                import drive

print("Versão:",torch.__version__)
# Out:
# Versão: 2.0.1+cu118

# %% [markdown]
# ## Leitura de dados

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
! mkdir ~/.kaggle

# %%
! cp /content/gdrive/MyDrive/kaggle_api/kaggle.json ~/.kaggle/kaggle.json

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download -d shiekhburhan/face-mask-dataset
# Out:
# Downloading face-mask-dataset.zip to /content
#  99% 2.32G/2.33G [00:26<00:00, 34.6MB/s]
# 100% 2.33G/2.33G [00:26<00:00, 93.5MB/s]

# %%
! unzip face-mask-dataset.zip
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#   inflating: FMD_DATASET/with_mask/simple/simple771.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple772.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple773.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple774.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple775.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple776.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple777.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple778.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple779.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple78.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple780.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple781.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple782.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple783.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple784.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple785.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple786.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple787.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple788.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple789.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple79.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple790.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple791.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple792.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple793.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple794.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple795.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple796.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple797.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple798.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple799.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple8.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple80.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple800.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple801.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple802.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple803.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple804.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple805.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple806.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple807.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple808.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple809.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple81.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple810.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple811.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple812.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple813.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple814.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple815.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple816.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple817.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple818.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple819.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple82.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple820.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple821.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple822.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple823.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple824.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple825.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple826.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple827.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple828.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple829.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple83.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple830.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple831.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple832.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple833.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple834.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple835.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple836.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple837.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple838.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple839.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple84.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple840.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple841.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple842.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple843.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple844.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple845.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple846.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple847.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple848.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple849.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple85.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple850.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple851.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple852.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple853.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple854.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple855.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple856.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple857.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple858.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple859.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple86.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple860.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple861.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple862.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple863.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple864.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple865.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple866.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple867.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple868.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple869.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple87.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple870.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple871.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple872.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple873.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple874.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple875.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple876.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple877.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple878.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple879.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple88.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple880.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple881.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple882.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple883.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple884.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple885.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple886.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple887.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple888.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple889.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple89.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple890.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple891.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple892.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple893.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple894.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple895.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple896.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple897.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple898.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple899.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple9.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple90.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple900.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple901.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple902.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple903.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple904.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple905.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple906.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple907.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple908.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple909.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple91.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple910.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple911.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple912.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple913.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple914.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple915.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple916.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple917.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple918.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple919.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple92.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple920.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple921.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple922.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple923.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple924.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple925.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple926.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple927.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple928.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple929.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple93.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple930.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple931.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple932.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple933.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple934.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple935.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple936.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple937.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple938.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple939.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple94.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple940.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple941.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple942.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple943.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple944.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple945.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple946.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple947.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple948.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple949.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple95.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple950.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple951.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple952.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple953.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple954.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple955.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple956.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple957.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple958.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple959.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple96.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple960.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple961.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple962.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple963.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple964.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple965.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple966.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple967.jpg
#   inflating: FMD_DATASET/with_mask/simple/simple968.jpg
#   inflating: FMD_DATASET/with_mask/simple/sim
jpg
#   inflating: FMD_DATASET/without_mask/simple/simple886.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple887.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple888.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple889.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple89.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple890.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple891.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple892.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple893.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple894.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple895.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple896.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple897.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple898.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple899.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple9.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple90.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple900.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple901.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple902.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple903.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple904.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple905.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple906.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple907.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple908.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple909.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple91.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple910.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple911.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple912.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple913.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple914.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple915.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple916.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple917.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple918.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple919.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple92.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple920.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple921.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple922.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple923.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple924.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple925.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple926.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple927.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple928.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple929.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple93.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple930.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple931.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple932.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple933.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple934.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple935.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple936.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple937.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple938.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple939.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple94.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple940.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple941.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple942.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple943.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple944.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple945.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple946.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple947.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple948.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple949.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple95.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple950.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple951.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple952.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple953.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple954.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple955.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple956.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple957.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple958.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple959.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple96.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple960.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple961.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple962.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple963.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple964.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple965.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple966.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple967.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple968.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple969.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple97.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple970.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple971.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple972.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple973.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple974.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple975.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple976.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple977.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple978.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple979.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple98.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple980.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple981.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple982.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple983.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple984.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple985.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple986.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple987.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple988.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple989.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple99.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple990.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple991.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple992.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple993.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple994.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple995.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple996.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple997.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple998.jpg
#   inflating: FMD_DATASET/without_mask/simple/simple999.jpg

# %% [markdown]
# ## Tratamento de dados

# %%
categorias = ['incorrect','with','without']

# %%
# Define as transformações que serão aplicadas nas imagens
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

# Define o caminho para a pasta contendo as imagens
data_path = '/content/FMD_DATASET/'

# Cria o dataset usando a classe ImageFolder
dataset = ImageFolder(root=data_path, transform=transform)

# Verifica a quantidade de rótulos
num_labels = len(dataset.classes)

# Imprime a quantidade de rótulos
print("Quantidade de rótulos:", num_labels)

# Define a proporção de divisão (por exemplo, 80% para treinamento e 20% para teste)
train_ratio = 0.8
dataset_size = len(dataset)
train_size = int(train_ratio * dataset_size)
test_size = dataset_size - train_size

# Divide o dataset em treinamento e teste
train_dataset, test_dataset = random_split(dataset, [train_size, test_size])

# Cria um DataLoader para carregar os dados de treinamento em lotes
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)

# Cria um DataLoader para carregar os dados de teste em lotes
test_dataloader = DataLoader(test_dataset, batch_size=32, shuffle=False)
# Out:
# Quantidade de rótulos: 3

# %%
print(len(train_dataloader)*32, len(test_dataloader)*32)
# Out:
# 11648 2912

# %% [markdown]
# ## Model

# %%
# Definir o modelo
class Classificador(nn.Module):
    def __init__(self):
        super(Classificador, self).__init__()

        self.conv_layers = nn.Sequential(
            nn.Conv2d(3, 32, 3),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(32, 64, 3),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, 3),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )

        self.dense_layers = nn.Sequential(
            nn.Flatten(),
            nn.Linear(128 * 26 * 26, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(256, 3)
        )

    def forward(self, x):
        x = self.conv_layers(x)
        x = self.dense_layers(x)
        return x

# %%
model = Classificador()
optimizer = torch.optim.Adam(model.parameters(), lr= 0.001)
criterion = nn.CrossEntropyLoss()

# %%
device = torch.device("cuda") if torch.cuda.is_available() else torch.device("cpu")
print(device,"\n")

model.to(device)
# Out:
# cpu
# Classificador(
#   (conv_layers): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1))
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1))
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (dense_layers): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=86528, out_features=512, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.5, inplace=False)
#     (4): Linear(in_features=512, out_features=256, bias=True)
#     (5): ReLU()
#     (6): Dropout(p=0.5, inplace=False)
#     (7): Linear(in_features=256, out_features=3, bias=True)
#   )
# )

# %% [markdown]
# ## Fit

# %%
def train(model, dataLoader, criterion, optimizer):
    model.train()
    cumloss = 0.0
    for imagens, rotulos in dataLoader:
        imagens = imagens.to(device)
        rotulos = rotulos.to(device)

        pred = model(imagens)
        loss = criterion(pred, rotulos)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        cumloss += loss.item()

    return cumloss / len(dataLoader)


def validacao(model, dataLoader, lossfunc):
    model.eval()
    cumloss = 0.0

    with torch.no_grad():
        for imgs, labels in dataLoader:

            imgs, labels = imgs.to(device), labels.to(device)

            pred = model(imgs)

            loss = lossfunc(pred, labels)

            cumloss += loss.item()

    return cumloss / len(dataLoader)

epochs = 2
losses_treino = []
losses_teste = []

for i in range(epochs):
  loss_treino = train(model, train_dataloader, criterion, optimizer)
  losses_treino.append(loss_treino)
  if (i%2==0):
    print(f"Época: {i}; Loss Treino: {loss_treino}")

  loss_val = validacao(model, test_dataloader, criterion)
  losses_teste.append(loss_val)
# Out:
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:975: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Época: 0; Loss Treino: 0.27548361308412156

# %% [markdown]
# ## Metricas

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

def plot_loss(losses):
    fig = plt.figure(figsize=(13,5))
    ax = fig.gca()
    for loss_name, loss_values in losses.items():
        ax.plot(loss_values, label=loss_name)
    ax.legend(fontsize="16")
    ax.set_xlabel("Epoch", fontsize="16")
    ax.set_ylabel("Loss", fontsize="16")
    ax.set_title("Loss vs epochs", fontsize="16")
    plt.show()

def make_confusion_matrix(model, loader, num_classes):
    confusion_matrix = np.zeros((num_classes, num_classes), dtype=np.int64)
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            output = model(images)
            _, predictions = torch.max(output, 1)
            for label, prediction in zip(labels.view(-1), predictions.view(-1)):
                confusion_matrix[label, prediction] += 1
    return confusion_matrix

def evaluate_metrics(model, loader, classes, verbose=True):
    pred_correct = {classname: 0 for classname in classes}
    total_pred = {classname: 0 for classname in classes}

    confusion_matrix = make_confusion_matrix(model, loader, len(classes))

    if verbose:
        total_correct = 0.0
        total_predicted = 0.0

        for i, classname in enumerate(classes):
            correct_count = confusion_matrix[i, i]
            class_pred = np.sum(confusion_matrix[i])

            total_correct += correct_count
            total_predicted += class_pred

            accuracy = 100 * correct_count / class_pred
            precision = precision_score(confusion_matrix[:, i], confusion_matrix[i, :])
            recall = recall_score(confusion_matrix[:, i], confusion_matrix[i, :])
            f1 = f1_score(confusion_matrix[:, i], confusion_matrix[i, :])

            print("Class {}: Accuracy: {:.2f}, Precision: {:.2f}, Recall: {:.2f}, F1-score: {:.2f}".format(
                classname, accuracy, precision, recall, f1))

        print("Overall Accuracy: {:.2f}".format(100 * total_correct / total_predicted))

    return confusion_matrix

def test(model, loader, classes):
    pred_correct = {classname: 0 for classname in classes}
    total_pred = {classname: 0 for classname in classes}

    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            output = model(images)
            _, predictions = torch.max(output, 1)
            for label, prediction in zip(labels, predictions):
                if label == prediction:
                    pred_correct[classes[label]] += 1
                total_pred[classes[label]] += 1

    total_correct = 0.0
    total_predicted = 0.0
    for class_name, correct_count in pred_correct.items():
        total_correct += correct_count
        total_predicted += total_pred[class_name]
        accuracy = 100 * correct_count / total_pred[class_name]
        print("Class {}: Accuracy: {:.2f}".format(class_name, accuracy))
    print("Overall Accuracy: {:.2f}".format(100 * total_correct / total_predicted))

# %%
def plot_loss_and_accuracy(losses, accuracies):
    fig, ax1 = plt.subplots(figsize=(12, 6))
    ax2 = ax1.twinx()

    for loss_name, loss_values in losses.items():
        ax1.plot(loss_values, label=loss_name, color='tab:red')
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Loss", color='tab:red')
    ax1.tick_params(axis='y', labelcolor='tab:red')
    ax1.legend(loc='upper left')

    for accuracy_name, accuracy_values in accuracies.items():
        ax2.plot(accuracy_values, label=accuracy_name, color='tab:blue')
    ax2.set_ylabel("Accuracy", color='tab:blue')
    ax2.tick_params(axis='y', labelcolor='tab:blue')
    ax2.legend(loc='upper right')

    fig.tight_layout()
    plt.show()

def make_confusion_matrix(model, loader, num_classes):
    confusion_matrix = np.zeros((num_classes, num_classes), dtype=np.int64)
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            output = model(images)
            _, predictions = torch.max(output, 1)
            for label, prediction in zip(labels.view(-1), predictions.view(-1)):
                confusion_matrix[label, prediction] += 1
    return confusion_matrix

def evaluate_metrics(model, loader, classes, verbose=True):
    pred_correct = {classname: 0 for classname in classes}
    total_pred = {classname: 0 for classname in classes}
    accuracies = {classname: [] for classname in classes}

    confusion_matrix = make_confusion_matrix(model, loader, len(classes))

    if verbose:
        total_correct = 0.0
        total_predicted = 0.0
        losses = []

        for i, classname in enumerate(classes):
            correct_count = confusion_matrix[i, i]
            class_pred = np.sum(confusion_matrix[i])

            total_correct += correct_count
            total_predicted += class_pred

            accuracy = 100 * correct_count / class_pred
            precision = precision_score(confusion_matrix[:, i], confusion_matrix[i, :])
            recall = recall_score(confusion_matrix[:, i], confusion_matrix[i, :])
            f1 = f1_score(confusion_matrix[:, i], confusion_matrix[i, :])

            print("Class {}: Accuracy: {:.2f}, Precision: {:.2f}, Recall: {:.2f}, F1-score: {:.2f}".format(
                classname, accuracy, precision, recall, f1))

            accuracies[classname].append(accuracy)

        print("Overall Accuracy: {:.2f}".format(100 * total_correct / total_predicted))

    return confusion_matrix, accuracies

def test(model, loader, classes):
    pred_correct = {classname: 0 for classname in classes}
    total_pred = {classname: 0 for classname in classes}
    with torch.no_grad():
        for images, labels in loader:
            images, labels = images.to(device), labels.to(device)
            output = model(images)
            _, predictions = torch.max(output, 1)
            for label, prediction in zip(labels, predictions):
                if label == prediction:
                    pred_correct[classes[label]] += 1
                total_pred[classes[label]] += 1

    total_correct = 0.0
    total_predicted = 0.0
    for class_name, correct_count in pred_correct.items():
        total_correct += correct_count
        total_predicted += total_pred[class_name]
        accuracy = 100 * correct_count / total_pred[class_name]
        print("Class {}: Accuracy: {:.2f}".format(class_name, accuracy))
    print("Overall Accuracy: {:.2f}".format(100 * total_correct / total_predicted))

# %%
grafico_de_loss = {'Loss de treino':losses_treino,
                  'Loss de teste':losses_teste}
plot_loss(grafico_de_loss)

# %%
categorias = ['incorrect','with','without']

test(model, test_dataloader, categorias)
# Out:
# Class withmask: Accuracy: 97.08
# Class withoutmask: Accuracy: 94.58
# Class mask: Accuracy: 91.60
# Overall Accuracy: 94.50

# %%
matriz = make_confusion_matrix(model, test_dataloader, 3)

plt.figure(figsize=(8, 7))
sns.set(font_scale=1.4)
sns.heatmap(matriz.tolist(),
           annot=True, annot_kws={"size": 16}, fmt='d', cmap='viridis')
# Out:
# <Axes: >
